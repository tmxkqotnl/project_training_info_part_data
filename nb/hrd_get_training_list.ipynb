# %%
import init
from controller import get_all_training_list

# %%
# opts = {
#         "authKey": "serviceKey",
#         "returnType": "XML",  # only XML avaliable
#         "outType": "1",  # 1 - list
#         "pageNum": "1",  # maximum 1000
#         "pageSize": "100",  # maximum 100
        
#         "srchTraArea1":"", # 훈련지역 대분류
#         "srchTraArea2":"", # 훈련지역 중분류
        
#         "srchKeco1":"", # 훈련분야 대분류
#         "srchKeco2":"", # 훈련분야 중분류
#         "srchKeco3":"", # 훈련분야 소분류
        
#         "crseTracseSe":"", # 훈련유형 # 중장년특화 X
        
#         "srchTraGbn":"", # 훈련구분코드 # 중장년특화 X
#         "srchTraType":"", # 훈련종류
        
#         "sort": "ASC", 정렬방법
#         "sortCol": "TR_STT_DT",  # TOT_FXNUM - 모집인원, TR_STT_DT - 훈련시작일, TR_NM_i - 훈련과정명

#         "srchTraStDt": "19700101",  # 훈련 시작일 from
#         "srchTraEndDt": "20221231",  # 훈련 시작일 to

#         "srchTraProcessNm":"", # 훈련과정명
#         "srchTraOrganNm":"", # 훈련기관명
# }

# %%
a = get_all_training_list()

# %%
import datetime
dt = str(int(datetime.datetime.now().timestamp()))

a.to_csv(''.join(['../files/for_job_hunter/구직자훈련과정',str(dt),'.csv']),index=False)

# %%
a
# Out:
#             주소 컨텐츠      수강비 등급    훈련기관_코드    NCS_코드   실제_훈련비 수강신청_인원  정원  \
# 0       충북 충주시      5695890     200400383  19010701  5695890       0  26
# 1        울산 동구       722400     201001850  06010108   722400       0  34
# 2       전남 순천시       979750     201601953  13010101   979750       0  20
# 3      서울 동대문구      1218700     201501690  02040102  1218700       0  30
# 4      부산 부산진구      2305800     202100012  20010207  2305800       0  30
# ..         ...  ..      ... ..        ...       ...      ...     ...  ..
# 95      서울 종로구       489380     200400741  21020102   489380      15  20
# 96       대구 중구      1359400     200600463  21020101  1359400      16  18
# 97       대구 서구      1196000     201502374  15010201  1196000       4  15
# 98  경기 고양시 덕양구       719400     200300071  02020302   719400       3  10
# 99  충남 천안시 서북구      1681680     200901646  12010104  1681680      12  16
#
#                                                    제목               부제목  \
# 0                                     (내선공사)내선공사 양성과정          충주직업전문학교
# 1                                      요양보호사 자격증 취득과정        새롬요양보호사교육원
# 2                         한식조리기능사 자격 취득(이론+실기)및 밑반찬실무      전남직업전문학교주식회사
# 3                      ERP정보관리(회계,인사,물류,생산)사무원양성과정 C반         국민법률세무교육원
# 4                            UI/UX기반 프론트엔드 개발자 양성 과정A  코리아아이티(IT)아카데미학원
# ..                                                ...               ...
# 95                                          천연발효건강빵과정      종로호텔제과직업전문학교
# 96                                 제과제빵자격증취득과정(이론+실기)        대구제과제빵커피학원
# 97  스마트 기계요소설계 (AutoCAD / Inventor / 기계부품 3D프린팅) 양성과정           3D프린팅학원
# 98                ITQ OA MASTER(한글, 엑셀, 파워포인트) 자격증 취득         벽제중앙컴퓨터학원
# 99                                  미용사(네일)국가자격증 취득과정        나레스트천안미용학원
#
#      주관부처          전화번호      훈련시작일자      훈련종료일자         훈련대상   훈련구분  \
# 0   고용노동부  043-853-7499  2022-12-30  2023-06-29   국가기간전략산업직종  C0061
# 1   고용노동부  052-201-6801  2022-12-30  2023-02-13  내일배움카드(구직자)  C0061
# 2   고용노동부  061-811-3005  2022-12-30  2023-02-24  내일배움카드(구직자)  C0061
# 3   고용노동부  02-2135-3669  2022-12-29  2023-02-08  내일배움카드(구직자)  C0061
# 4   고용노동부  051-914-5890  2022-12-27  2023-05-02  내일배움카드(구직자)  C0061
# ..    ...           ...         ...         ...          ...    ...
# 95  고용노동부   02-736-1158  2021-01-18  2021-03-22  내일배움카드(구직자)  C0061
# 96  고용노동부  053-426-2858  2021-01-18  2021-03-31  내일배움카드(구직자)  C0061
# 97  고용노동부  053-253-0211  2021-01-18  2021-03-31  내일배움카드(구직자)  C0061
# 98  고용노동부  031-962-3841  2021-01-18  2021-03-17  내일배움카드(구직자)  C0061
# 99  고용노동부  041-551-7551  2021-01-18  2021-04-21  내일배움카드(구직자)  C0061
#
#           훈련기관ID             훈련과정ID 훈련과정_순차
# 0   500020019651  AIG20210000337552       1
# 1   500020024673  AIG20210000346620       9
# 2   500020042082  AIG20210000354067       2
# 3   500020034211  AIG20210000334333       1
# 4   500038884832  AIG20210000362125       2
# ..           ...                ...     ...
# 95  500020021207  AIG20200000291120       1
# 96  500020019416  AIG20200000289465       1
# 97  500020030798  AIG20200000293420       1
# 98  500020056902  AIG20200000289136       1
# 99  500020016305  AIG20200000285506       2
#
# [171277 rows x 20 columns]
