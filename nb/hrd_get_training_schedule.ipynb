# %%
import init
import os

# %%
from Class import URL
from const import TRAINING_FOR_JOB_HUNTER,INFO_TYPE

# %% [markdown]
# - 'A‘ : 개설예정
# - ‘B‘ : 진행중
# - ‘C‘ : 미실시
# - ‘D‘ : 수료자 없음
# - 숫자 : 취업률

# %%
url = URL()

params = {
    'authKey':os.getenv('HRD_API_KEY'),
    'returnType':'XML',
    'outType':'2',
    'srchTrprId':'AIG20210000346620',
}

url.set_parameter(params)
url.set_url(TRAINING_FOR_JOB_HUNTER[INFO_TYPE['훈련일정']])

import requests
from controller.url_controller import get_full_url

get_full_url(url)
# requests.get(get_full_url(url))
# Out:
# 'https://www.hrd.go.kr/jsp/HRDP/HRDPO00/HRDPOA60/HRDPOA60_3.jsp?authKey=hfI6LTOnqD5609y88FO2DHzf2OGCuFeO&returnType=XML&outType=2&srchTrprId=AIG20210000346620'

# %%
from controller.training_schedule import get_traininig_schedule_info, get_training_schedule_info_list
get_traininig_schedule_info(url,'AIG20210000346620')
# Out:
#   3개월_고용보험_취업률(pct) 3개월_고용보험_취업인원 6개월_고용보험_취업률(pct) 6개월_고용보험_취업인원  \
# 0                 D          None                 B          None
# 1                 B          None                 B          None
# 2                 B          None                 B          None
# 3                 B          None                 B          None
# 4                 A          None                 A          None
# 5                 A          None                 A          None
# 6                 A          None                 A          None
# 7                 A          None                 A          None
# 8                 A          None                 A          None
# 9                 A          None                 A          None
#
#   6개월_고용보험_미가입_취업률(pct) 6개월_고용보험_미가입_취업인원        훈련기관 코드 모집인원(정원) 수강인원  \
# 0                   0.0                 0  6208136408000       34    0
# 1                   0.0                 0  6208136408000       34    5
# ...

# %%
import pandas as pd

get_training_schedule_info_list(url,pd.DataFrame({
    '훈련과정ID':['AVA20223000828644','AVA20223000828648','AVA20223000830860'],
    '훈련과정_순차':[None,'7','21']
}))
# Out:
#   3개월_고용보험_취업률(pct) 3개월_고용보험_취업인원 6개월_고용보험_취업률(pct) 6개월_고용보험_취업인원  \
# 0                 D          None                 B          None
# 1                 B          None                 B          None
# 2                 B          None                 B          None
# 3                 A          None                 A          None
# 0                 A          None                 A          None
# 0                 A          None                 A          None
#
#   6개월_고용보험_미가입_취업률(pct) 6개월_고용보험_미가입_취업인원        훈련기관 코드 모집인원(정원) 수강인원 총_훈련비  \
# 0                   0.0                 0  2003035159800      500    0     0
# 1                   0.0                 0  2003035159800      500    0     0
# 2                   0.0                 0  2003035159800      500    0     0
# 3                   0.0                 0  2003035159800      500    0     0
# 0                   0.0                 0  2003035159800      500    0     0
# ...
