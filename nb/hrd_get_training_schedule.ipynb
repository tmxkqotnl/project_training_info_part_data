# %%
import init
import os

# %%
from Class import URL
from const import TRAINING_FOR_WORKER,TRAINING_FOR_ENTERPRISE,TRAINING_FOR_MIDDLE_AGED,TRAINING_FOR_JOB_HUNTER,INFO_TYPE
from training_list_controller import get_training_list
from training_schedule_controller import get_training_schedule_info_list, get_training_schedule_info

# %% [markdown]
# - 'A‘ : 개설예정
# - ‘B‘ : 진행중
# - ‘C‘ : 미실시
# - ‘D‘ : 수료자 없음
# - 숫자 : 취업률

# %%
url_schedule = URL()
url_schedule.set_parameter({
    'authKey':os.getenv('HRD_API_KEY'),
    'returnType':'XML',
    'outType':'2',
    'srchTrprId':'AIG20210000346620',
    'srchTrprDegr':1
})

url_tr_lst = URL()
url_tr_lst.set_parameter({
    'authKey':os.getenv('HRD_API_KEY'),
    "returnType": "XML", 
    "outType": "1", 
    "pageNum": "1",  
    "pageSize": "10", 
    "sortCol": "TR_STT_DT", 
    "srchTraStDt": "19700101",  
    "srchTraEndDt": "20301231",
    "sort":'DESC'
})

# %%
# 구직자 훈련과정
url_schedule.set_url(TRAINING_FOR_JOB_HUNTER[INFO_TYPE['훈련일정']])
url_tr_lst.set_url(TRAINING_FOR_JOB_HUNTER[INFO_TYPE['목록']])

lst = get_training_list(url_tr_lst)
get_training_schedule_info_list(url_schedule,lst)
# Out:
#   3개월_고용보험_취업률(pct) 3개월_고용보험_취업인원 6개월_고용보험_취업률(pct) 6개월_고용보험_취업인원  \
# 0                 A          None                 A          None
# 0                 A          None                 A          None
# 0                 A          None                 A          None
# 0                 A          None                 A          None
# 0                 A          None                 A          None
# 0                 A          None                 A          None
# 0                 A          None                 A          None
# 0                 A          None                 A          None
# 0                 A          None                 A          None
# 0                 A          None                 A          None
#
#   6개월_고용보험_미가입_취업률(pct) 6개월_고용보험_미가입_취업인원        훈련기관 코드 모집인원(정원) 수강인원  \
# 0                   0.0                 0  1998333020700       26    0
# 0                   0.0                 0  2007037513202       20    0
# ...

# %%
# 근로자 훈련과정
url_schedule.set_url(TRAINING_FOR_WORKER[INFO_TYPE['훈련일정']])
url_tr_lst.set_url(TRAINING_FOR_WORKER[INFO_TYPE['목록']])

lst = get_training_list(url_tr_lst)
get_training_schedule_info_list(url_schedule,lst)
# Out:
#   3개월_고용보험_취업률(pct) 3개월_고용보험_취업인원 6개월_고용보험_취업률(pct) 6개월_고용보험_취업인원  \
# 0              None          None              None          None
# 0              None          None              None          None
# 0              None          None              None          None
# 0              None          None              None          None
# 0              None          None              None          None
# 0              None          None              None          None
# 0              None          None              None          None
# 0              None          None              None          None
# 0              None          None              None          None
# 0              None          None              None          None
#
#   6개월_고용보험_미가입_취업률(pct) 6개월_고용보험_미가입_취업인원        훈련기관 코드 모집인원(정원) 수강인원  \
# 0                  None              None  2148897548000      500    0
# 0                  None              None  2148897548000      100    0
# ...

# %%
# 기업 훈련과정
url_schedule.set_url(TRAINING_FOR_ENTERPRISE[INFO_TYPE['훈련일정']])
url_tr_lst.set_url(TRAINING_FOR_ENTERPRISE[INFO_TYPE['목록']])

lst = get_training_list(url_tr_lst)
get_training_schedule_info_list(url_schedule,lst)
# Out:
#   3개월_고용보험_취업률(pct) 3개월_고용보험_취업인원 6개월_고용보험_취업률(pct) 6개월_고용보험_취업인원  \
# 0              None          None              None          None
# 0              None          None              None          None
# 0              None          None              None          None
# 0              None          None              None          None
# 0              None          None              None          None
# 0              None          None              None          None
# 0              None          None              None          None
# 0              None          None              None          None
# 0              None          None              None          None
# 0              None          None              None          None
#
#   6개월_고용보험_미가입_취업률(pct) 6개월_고용보험_미가입_취업인원        훈련기관 코드 모집인원(정원) 수강인원  총_훈련비  \
# 0                  None              None  2007065549900      150    0      0
# 0                  None              None  2007065549900      150    0      0
# ...

# %%
# 중장년층 훈련과정
url_schedule.set_url(TRAINING_FOR_MIDDLE_AGED[INFO_TYPE['훈련일정']])
url_tr_lst.set_url(TRAINING_FOR_MIDDLE_AGED[INFO_TYPE['목록']])

lst = get_training_list(url_tr_lst)
get_training_schedule_info_list(url_schedule,lst)
# Out:
#   3개월_고용보험_취업률(pct) 3개월_고용보험_취업인원 6개월_고용보험_취업률(pct) 6개월_고용보험_취업인원  \
# 0              23.1             3              38.5             5
# 0              42.9             3              42.9             3
# 0              81.8             9              90.9            10
# 0              35.3             6              58.8            10
# 0              55.6             5             100.0             9
# 0              25.0             2              62.5             5
# 0              42.1             8              63.2            12
# 0              16.7             2              41.7             5
# 0              21.4             3              50.0             7
# 0               8.3             1              16.7             2
#
#   6개월_고용보험_미가입_취업률(pct) 6개월_고용보험_미가입_취업인원        훈련기관 코드 모집인원(정원) 수강인원  \
# 0                   0.0                 0  2000060357101       20    5
# 0                  14.3                 1  1998466570500       20    0
# ...

# %%
url_schedule.set_parameter({'srchTrprDegr':None})
get_training_schedule_info(url_schedule,'AIG20210000346620')
# Out:
#   3개월_고용보험_취업률(pct) 3개월_고용보험_취업인원 6개월_고용보험_취업률(pct) 6개월_고용보험_취업인원  \
# 0                 D          None                 B          None
# 1              14.3             1              28.6             2
# 2               5.3             1              26.3             5
# 3               5.6             1              11.1             2
# 4              10.5             2              10.5             2
# 5              11.1             2              16.7             3
# 6              11.1             2              16.7             3
# 7              12.5             2              31.3             5
# 8               0.0             0               0.0             0
# 9               8.3             1              16.7             2
#
#   6개월_고용보험_미가입_취업률(pct) 6개월_고용보험_미가입_취업인원        훈련기관 코드 모집인원(정원) 수강인원  \
# 0                   0.0                 0  9090142277100       20    0
# 1                  57.1                 4  9090142277100       20    0
# ...

# %%
import pandas as pd

get_training_schedule_info_list(url_schedule,pd.DataFrame({
    '훈련과정ID':['AVA20223000828644','AVA20223000828648','AVA20223000830860'],
    '훈련과정_순차':[None,'7','21']
}))
# Out:
#    3개월_고용보험_취업률(pct) 3개월_고용보험_취업인원 6개월_고용보험_취업률(pct) 6개월_고용보험_취업인원  \
# 0                  D          None                 B          None
# 1                  B          None                 B          None
# 2                  B          None                 B          None
# 3                  A          None                 A          None
# 4                  A          None                 A          None
# 5                  A          None                 A          None
# 6                  A          None                 A          None
# 7                  A          None                 A          None
# 8                  A          None                 A          None
# 9                  A          None                 A          None
# 10                 A          None                 A          None
# 11                 A          None                 A          None
# 12                 A          None                 A          None
# ...
